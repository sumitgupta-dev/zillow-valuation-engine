# %%
import pandas as pd

# Load the data
df = pd.read_csv('../data/kc_house_data.csv')

# Grab the 4 columns and turn into pure NumPy array (just like in main.py)
db_features = df[['sqft_living', 'bedrooms', 'bathrooms', 'floors']].values

# The Experiment: Look at the first 5 rows
for index, row in enumerate(db_features):
    print(f"Index: {index} | Row Data: {list(row)}")
    if index == 4:  # Stop after 5 houses
        break
# Out:
# Index: 0 | Row Data: [np.float64(1180.0), np.float64(3.0), np.float64(1.0), np.float64(1.0)]
# Index: 1 | Row Data: [np.float64(2570.0), np.float64(3.0), np.float64(2.25), np.float64(2.0)]
# Index: 2 | Row Data: [np.float64(770.0), np.float64(2.0), np.float64(1.0), np.float64(1.0)]
# Index: 3 | Row Data: [np.float64(1960.0), np.float64(4.0), np.float64(3.0), np.float64(1.0)]
# Index: 4 | Row Data: [np.float64(1680.0), np.float64(3.0), np.float64(2.0), np.float64(1.0)]
